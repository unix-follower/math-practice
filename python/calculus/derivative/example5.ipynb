# %% [markdown]
# References
# ----------
# [1] https://openstax.org/books/calculus-volume-1/pages/3-1-defining-the-derivative
#
# [2] Checkpoint 3.5
# $$
# \begin{equation}
# P(s)=-20s^2+150s-10
# \end{equation}
# $$

# %%
import sympy as sp
from sympy.abc import x
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

print(f"SymPy version: {sp.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print()

f = sp.Lambda(x, -20 * x ** 2 + 150 * x - 10)
print(f)

x_values = np.arange(0, 5)
print(f"x:{x_values}")
y_values = list(map(f, x_values))
print(f"y:{y_values}")

f_prime = sp.diff(f(x), x)
x_at = 3.25
slope = f_prime.subs(x, x_at).evalf()
print(f"The slope of the tangent at x={x_at}: {slope}")
y_tangent = slope * (x_values - x_at) + f(x_at).evalf()
print(f"y_tangent:{y_tangent}")

figure, axes = plt.subplots(figsize=(6, 3))
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title(f.expr)
axes.grid()
axes.plot(x_values, y_values, marker="o", markersize=5)
axes.plot(x_values, y_tangent, label=f"The slope at x={x_at} (slope={slope:.2f})", linestyle="--")
axes.legend()
plt.show()
# Out:
# SymPy version: 1.12
# NumPy version: 1.26.4
# Matplotlib version: 3.8.4
#
# Lambda(x, -20*x**2 + 150*x - 10)
# x:[0 1 2 3 4]
# y:[-10, 120, 210, 260, 270]
# The slope of the tangent at x=3.25: 20.0000000000000
# y_tangent:[201.250000000000 221.250000000000 241.250000000000 261.250000000000
#  281.250000000000]
