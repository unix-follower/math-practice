# %% [markdown]
# References
# ----------
# [1] https://openstax.org/books/calculus-volume-1/pages/3-6-the-chain-rule
#
# [2] Checkpoint 3.36
# $$
# \begin{equation}
# h(x)=sin(7x+2)
# \end{equation}
# $$

# %%
import sympy as sp
from sympy.abc import x
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

print(f"SymPy version: {sp.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print()

f = sp.Lambda(x, sp.sin(7 * x + 2))
print(f)

x_values = np.linspace(-5, 5, 21)
print(f"x:{x_values}")
y_values = list(map(f, x_values))
print(f"y:{y_values}")

f_prime = sp.diff(f(x), x)
print(f"f′(x)={f_prime}")

figure, axes = plt.subplots(figsize=(6, 3))
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title(f.expr)
axes.grid()
axes.plot(x_values, y_values, marker="o", markersize=5)
plt.show()
# Out:
# SymPy version: 1.13.2
# NumPy version: 1.26.4
# Matplotlib version: 3.9.2
#
# Lambda(x, sin(7*x + 2))
# x:[-5.  -4.5 -4.  -3.5 -3.  -2.5 -2.  -1.5 -1.  -0.5  0.   0.5  1.   1.5
#   2.   2.5  3.   3.5  4.   4.5  5. ]
# y:[-0.999911860107267, 0.941031408342954, -0.762558450479603, 0.487174512460510, -0.149877209662952, -0.206467481937797, 0.536572918000435, -0.798487112623490, 0.958924274663138, -0.997494986604054, sin(2), -0.705540325570392, 0.412118485241757, -0.0663218973512007, -0.287903316665065, 0.605539869719601, -0.846220404175171, 0.979357643103917, -0.988031624092862, 0.871140000169176, -0.643538133356999]
# f′(x)=7*cos(7*x + 2)
