# %% [markdown]
# References
# ----------
# [1] https://openstax.org/books/calculus-volume-1/pages/3-5-derivatives-of-trigonometric-functions
#
# [2] Checkpoint 3.29
# $$
# \begin{equation}
# f(x)=2tan x - 3 cot x
# \end{equation}
# $$

# %%
import sympy as sp
from sympy.abc import x
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

print(f"SymPy version: {sp.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print()

f = sp.Lambda(x, 2 * sp.tan(x) - 3 * sp.cot(x))
print(f)

x_values = np.linspace(-np.pi, np.pi, 25)
x_values = x_values[x_values != 0]
print(f"x:{x_values}")
y_values = list(map(f, x_values))
print(f"y:{y_values}")

f_prime = sp.diff(f(x), x)
print(f"f′(x)={f_prime.simplify()}")

x_at = 1

slope = f_prime.subs(x, x_at).evalf()
print(f"f′({x_at})={slope}")
y_tangent = slope * (x_values - x_at) + f(x_at).evalf()
print(f"y_tangent:{y_tangent}")

figure, axes = plt.subplots(figsize=(6, 3))
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title(f.expr)
axes.grid()
axes.plot(x_values, y_values, marker="o", markersize=5)
axes.plot(x_values, y_tangent, label=f"f′({x_at})={slope:.2f}", linestyle="--")
axes.legend()
plt.show()
# Out:
# SymPy version: 1.13.2
# NumPy version: 1.26.4
# Matplotlib version: 3.9.2
#
# Lambda(x, 2*tan(x) - 3*cot(x))
# x:[-3.14159265 -2.87979327 -2.61799388 -2.35619449 -2.0943951  -1.83259571
#  -1.57079633 -1.30899694 -1.04719755 -0.78539816 -0.52359878 -0.26179939
#   0.26179939  0.52359878  0.78539816  1.04719755  1.30899694  1.57079633
#   1.83259571  2.0943951   2.35619449  2.61799388  2.87979327  3.14159265]
# y:[-2.44968590297931e+16, -10.6602540378444, -4.04145188432738, -0.999999999999999, 1.73205080756887, 6.66025403784438, -3.26624787063907e+16, -6.66025403784439, -1.73205080756888, 1.00000000000000, 4.04145188432738, 10.6602540378444, -10.6602540378444, -4.04145188432738, -1.00000000000000, 1.73205080756887, 6.66025403784437, 3.26624787063907e+16, -6.66025403784440, -1.73205080756889, 0.999999999999999, 4.04145188432737, 10.6602540378444, 2.44968590297931e+16]
# f′(x)=2/cos(x)**2 + 3/sin(x)**2
# f′(1)=11.0878864239417
# y_tangent:[-44.7329713557281 -41.8301694779537 -38.9273676001792 -36.0245657224048
#  -33.1217638446304 -30.2189619668559 -27.3161600890815 -24.4133582113071
#  -21.5105563335326 -18.6077544557582 -15.7049525779838 -12.8021507002093
#  -6.99654694466045 -4.09374506688601 -1.19094318911158 1.71185868866286
#  4.61466056643729 7.51746244421173 10.4202643219862 13.3230661997606
#  16.2258680775350 19.1286699553095 22.0314718330839 24.9342737108583]
