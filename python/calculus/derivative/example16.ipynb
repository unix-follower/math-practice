# %% [markdown]
# References
# ----------
# [1] https://openstax.org/books/calculus-volume-1/pages/3-3-differentiation-rules
#
# [2] Checkpoint 3.20
# $$
# \begin{equation}
# f(x)=4x^2-3x+2
# \end{equation}
# $$
# $$
# \begin{equation}
# y=2x+3
# \end{equation}
# $$

# %%
import sympy as sp
from sympy.abc import x, y
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

print(f"SymPy version: {sp.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print()

f = sp.Lambda(x, 4 * x ** 2 - 3 * x + 2)
print(f)

x_values = np.linspace(0, 2, 20)
print(f"x:{x_values}")
y_values = list(map(f, x_values))
print(f"y:{y_values}")

f_prime = sp.diff(f(x), x)
print(f"f′:{f_prime.simplify()}")

x_at = 5/8

slope = f_prime.subs(x, x_at).evalf()
print(f"f′ at x={x_at}: {slope}")
y_tangent = slope * (x_values - x_at) + f(x_at).evalf()
print(f"y_tangent:{y_tangent}")

figure, axes = plt.subplots(figsize=(6, 3))
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title(f.expr)
axes.grid()
axes.plot(x_values, y_values, marker="o", markersize=5)
axes.plot(x_values, 2 * x_values + 3, label="y=2x+3", marker="o", markersize=5)
axes.plot(x_values, y_tangent, label=f"f′ at x={x_at} (slope={slope:.2f})", linestyle="--")
axes.legend()
plt.show()
# Out:
# SymPy version: 1.13.2
# NumPy version: 1.26.4
# Matplotlib version: 3.9.2
#
# Lambda(x, 4*x**2 - 3*x + 2)
# x:[0.         0.10526316 0.21052632 0.31578947 0.42105263 0.52631579
#  0.63157895 0.73684211 0.84210526 0.94736842 1.05263158 1.15789474
#  1.26315789 1.36842105 1.47368421 1.57894737 1.68421053 1.78947368
#  1.89473684 2.        ]
# y:[2, 1.72853185595568, 1.54570637119114, 1.45152354570637, 1.44598337950139, 1.52908587257618, 1.70083102493075, 1.96121883656510, 2.31024930747922, 2.74792243767313, 3.27423822714681, 3.88919667590028, 4.59279778393352, 5.38504155124654, 6.26592797783933, 7.23545706371191, 8.29362880886426, 9.44044321329640, 10.6759002770083, 12.0000000000000]
# f′:8*x - 3
# f′ at x=0.625: 2.00000000000000
# y_tangent:[0.437500000000000 0.648026315789474 0.858552631578947 1.06907894736842
#  1.27960526315789 1.49013157894737 1.70065789473684 1.91118421052632
#  2.12171052631579 2.33223684210526 2.54276315789474 2.75328947368421
#  2.96381578947368 3.17434210526316 3.38486842105263 3.59539473684211
#  3.80592105263158 4.01644736842105 4.22697368421053 4.43750000000000]
