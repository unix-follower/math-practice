# %% [markdown]
# References
# ----------
# [1] https://openstax.org/books/calculus-volume-1/pages/3-2-the-derivative-as-a-function
#
# [2] Checkpoint 3.9
# $$
# \begin{equation}
# f(x)=x^2
# \end{equation}
# $$

# %%
import sympy as sp
from sympy.abc import x
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

print(f"SymPy version: {sp.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print()

f = sp.Lambda(x, x ** 2)
print(f)

x_values = np.arange(0, 5)
print(f"x:{x_values}")
y_values = list(map(f, x_values))
print(f"y:{y_values}")

f_prime = sp.diff(f(x), x)
print(f"f′:{f_prime}")
f2_derivative = sp.diff(f(x), x, 2)
print(f"f′′:{f2_derivative}")

x_at = 3

slope = f_prime.subs(x, x_at).evalf()
print(f"f′ at x={x_at}: {slope}")
y_tangent = slope * (x_values - x_at) + f(x_at).evalf()
print(f"y_tangent:{y_tangent}")

slope2 = f2_derivative.subs(x, x_at).evalf()
print(f"f′′ at x={x_at}: {slope2}")
y2_tangent = slope2 * (x_values - x_at) + f(x_at).evalf()
print(f"y2_tangent:{y2_tangent}")

figure, axes = plt.subplots(figsize=(6, 3))
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title(f.expr)
axes.grid()
axes.plot(x_values, y_values, marker="o", markersize=5)
axes.plot(x_values, y_tangent, label=f"f′ at x={x_at} (slope={slope:.2f})", linestyle="--")
axes.plot(x_values, y2_tangent, label=f"f′′ at x={x_at} (slope={slope2:.2f})", linestyle="dashdot")
axes.legend()
plt.show()
# Out:
# SymPy version: 1.12
# NumPy version: 1.26.4
# Matplotlib version: 3.8.4
#
# Lambda(x, x**2)
# x:[0 1 2 3 4]
# y:[0, 1, 4, 9, 16]
# f′:2*x
# f′′:2
# f′ at x=3: 6.00000000000000
# y_tangent:[-9.00000000000000 -3.00000000000000 3.00000000000000 9.00000000000000
#  15.0000000000000]
# f′′ at x=3: 2.00000000000000
# y2_tangent:[3.00000000000000 5.00000000000000 7.00000000000000 9.00000000000000
#  11.0000000000000]
