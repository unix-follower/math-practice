# %% [markdown]
# References
# ----------
# [1] https://openstax.org/books/calculus-volume-1/pages/1-3-trigonometric-functions
#
# [2] Checkpoint 1.22
# $$
# \begin{equation}
#     f(x)=3sin(4x)-1
# \end{equation}
# $$

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

import sys
sys.path.insert(1, "../../utils")

from basic_units import degrees, radians

print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print()

def create_axes_values():
    theta = np.arange(0, 3, 0.09)
    print(theta)
    
    radial_distance = 3 * np.sin(4 * theta) - 1
    print(radial_distance)

    return theta, radial_distance


theta, radial_distance = create_axes_values()
x = [val*radians for val in theta]

figure, (axes1, axes2) = plt.subplots(2)
axes1.plot(x, radial_distance, xunits=radians)
axes2.plot(x, radial_distance, xunits=degrees)

figure = plt.figure()
axes = figure.add_subplot(projection="polar")
axes.plot(theta, radial_distance)
axes.grid(True)

plt.show()
# Out:
# NumPy version: 1.26.4
# Matplotlib version: 3.8.4
#
# [0.   0.09 0.18 0.27 0.36 0.45 0.54 0.63 0.72 0.81 0.9  0.99 1.08 1.17
#  1.26 1.35 1.44 1.53 1.62 1.71 1.8  1.89 1.98 2.07 2.16 2.25 2.34 2.43
#  2.52 2.61 2.7  2.79 2.88 2.97]
# [-1.          0.0568227   0.97815402  1.64587342  1.97437504  1.92154289
#   1.49415038  0.74699195 -0.22414195 -1.29474578 -2.32756133 -3.19017508
#  -3.77199448 -3.99842657 -3.84044133 -3.31829346 -2.49892565 -1.48738605
#  -0.41336045  0.58545422  1.38100359  1.87129318  1.99346474  1.7318551
#   1.12000429  0.23635546 -0.805802   -1.87285687 -2.82800595 -3.54879305
#  -3.94280869 -3.95953756 -3.59683492 -2.90120154]

# %% [markdown]
# $$
# \begin{equation}
#     y=sin(x)
# \end{equation}
# $$

# %%
def create_axes_values():
    theta = np.arange(0, 3, 0.09)
    print(theta)
    
    radial_distance = np.sin(theta)
    print(radial_distance)

    return theta, radial_distance


theta, radial_distance = create_axes_values()
x = [val*radians for val in theta]

figure, (axes1, axes2) = plt.subplots(2)
axes1.plot(x, radial_distance, xunits=radians)
axes2.plot(x, radial_distance, xunits=degrees)

figure = plt.figure()
axes = figure.add_subplot(projection="polar")
axes.plot(theta, radial_distance)
axes.grid(True)

plt.show()
# Out:
# [0.   0.09 0.18 0.27 0.36 0.45 0.54 0.63 0.72 0.81 0.9  0.99 1.08 1.17
#  1.26 1.35 1.44 1.53 1.62 1.71 1.8  1.89 1.98 2.07 2.16 2.25 2.34 2.43
#  2.52 2.61 2.7  2.79 2.88 2.97]
# [0.         0.08987855 0.17902957 0.26673144 0.35227423 0.43496553
#  0.51413599 0.58914476 0.65938467 0.72428717 0.78332691 0.83602598
#  0.88195781 0.9207506  0.95209034 0.97572336 0.99145835 0.99916795
#  0.99878974 0.9903268  0.97384763 0.94948561 0.91743796 0.87796406
#  0.83138346 0.7780732  0.71846479 0.65304075 0.58233065 0.50690685
#  0.42737988 0.34439347 0.25861935 0.17075183]
