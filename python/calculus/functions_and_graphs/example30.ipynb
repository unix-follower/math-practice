# %% [markdown]
# References
# ----------
# [1] https://openstax.org/books/calculus-volume-1/pages/1-4-inverse-functions
#
# [2] Checkpoint 1.24
# $$
# \begin{gather}
#     f(x)=\frac{3x}{x-2} \\
#     f^{-1}(y)=\frac{2y}{y-3}
# \end{gather}
# $$

# %%
import sympy as sp
from sympy import Lambda
from sympy.abc import x, y
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

print(f"SymPy version: {sp.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print()

f = Lambda(x, 3 * x / (x - 2))
print(f)
f_inverse = Lambda(y, 2 * y / (y - 3))
print(f_inverse)

x_values = np.arange(3, 11)
print("x:", x_values)

y_values = list(map(f, x_values))
print("y:", y_values)

y_values_inverse = list(map(f_inverse, y_values))
print("y (inverse):", y_values_inverse)

figure, axes = plt.subplots(figsize=(6, 3))
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title("Inverse Function")
axes.grid()
axes.plot(x_values, y_values, label=f.expr, marker="o", markersize=5)
axes.plot(x_values, y_values_inverse, label=f_inverse.expr, marker="o", markersize=5)
axes.legend()

plt.show()
# Out:
# SymPy version: 1.12
# NumPy version: 1.26.4
# Matplotlib version: 3.8.4
#
# Lambda(x, 3*x/(x - 2))
# Lambda(y, 2*y/(y - 3))
# x: [ 3  4  5  6  7  8  9 10]
# y: [9, 6, 5, 9/2, 21/5, 4, 27/7, 15/4]
# y (inverse): [3, 4, 5, 6, 7, 8, 9, 10]
